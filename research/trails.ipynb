# %%
import os
print(os.getcwd())
# Out:
# d:\Full_projects\CustomerChurn\research

# %%
os.chdir(r"D:\Full_projects\CustomerChurn")
print(os.getcwd())
# Out:
# D:\Full_projects\CustomerChurn

# %%
d={"key1":"value1","key2":"value2"}

# %%
d["key1"]
# Out:
# 'value1'

# %%
# #d.key1

# %%
# from box import ConfigBox

# %%
import sys
print(sys.executable)
# Out:
# d:\Full_projects\CustomerChurn\env\python.exe

# %%
from box import ConfigBox
print("Success")
# Out:
# Success

# %%
d2=ConfigBox({"key1":"value1","key2":"value2"})

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
d2.key1
# Out:
# 'value1'

# %%
# ensure_Annotation demo


def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(x=2,y=3)
# Out:
# 6

# %%
get_product(x=2,y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(x=2,y=3)
# Out:
# 6

# %%
get_product(x=2,y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 get_product(x=2,y="3")
#
# File d:\Full_projects\CustomerChurn\env\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000020FC9101080> does not match annotation type <class 'int'>
